# %%
pip install streamlit openai mem0ai google-generativeai assemblyai python-dotenv
# Out:
# Requirement already satisfied: streamlit in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (1.48.1)
# Requirement already satisfied: openai in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (1.100.2)
# Requirement already satisfied: mem0ai in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (0.1.116)
# Requirement already satisfied: google-generativeai in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (0.8.5)
# Requirement already satisfied: assemblyai in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (0.43.1)
# Requirement already satisfied: python-dotenv in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (1.1.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (2.3.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: posthog>=3.5.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from mem0ai) (6.6.0)
# Requirement already satisfied: qdrant-client>=1.9.1 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from mem0ai) (1.15.1)
# Requirement already satisfied: sqlalchemy>=2.0.31 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from mem0ai) (2.0.43)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from google-generativeai) (2.179.0)
# Requirement already satisfied: google-auth>=2.15.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from google-generativeai) (2.40.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: websockets>=11.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from assemblyai) (15.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from posthog>=3.5.0->mem0ai) (1.17.0)
# Requirement already satisfied: backoff>=1.10.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from posthog>=3.5.0->mem0ai) (2.2.1)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from qdrant-client>=1.9.1->mem0ai) (3.2.0)
# Requirement already satisfied: h2<5,>=3 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai) (4.2.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai) (4.1.0)
# Requirement already satisfied: greenlet>=1 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from sqlalchemy>=2.0.31->mem0ai) (3.2.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%writefile app.py
import os
import json
import requests
import streamlit as st
import google.generativeai as genai
from mem0 import MemoryClient
from dotenv import load_dotenv
load_dotenv()  # Loads variables from .env into environment

# --------------------------
# AssemblyAI for transcription
# --------------------------
import assemblyai as aai

ASSEMBLY_API_KEY = os.getenv("ASSEMBLYAI_API_KEY")  
aai.settings.api_key = ASSEMBLY_API_KEY


def transcribe_audio(audio_bytes) -> str:
    """Send audio bytes to AssemblyAI and return transcript text."""
    transcriber = aai.Transcriber()
    with open("temp_audio.wav", "wb") as f:
        f.write(audio_bytes)
    transcript = transcriber.transcribe("temp_audio.wav")
    return transcript.text if transcript and transcript.text else ""


# --------------------------
# Diabetes Health Assistant
# --------------------------
class DiabetesHealthAssistant:
    def __init__(self):
        self.languages = [
            "English", "Hindi", "Gujarati", "Bengali", "Tamil",
            "Telugu", "Kannada", "Malayalam", "Punjabi", "Marathi",
            "Urdu", "Assamese", "Odia", "Sanskrit"
        ]
        self.language_codes = {
            "English": "en", "Hindi": "hi", "Gujarati": "gu", "Bengali": "bn",
            "Tamil": "ta", "Telugu": "te", "Kannada": "kn", "Malayalam": "ml",
            "Punjabi": "pa", "Marathi": "mr", "Urdu": "ur", "Assamese": "as",
            "Odia": "or", "Sanskrit": "sa"
        }
        self.sutra_base_url = "https://api.two.ai/v2/chat/completions"

    def initialize_apis(self):
        try:
            genai.configure(api_key=os.getenv("GENAI_KEY"))
            self.gemini = genai.GenerativeModel("gemini-1.5-flash")
            self.gemini_logs = genai.GenerativeModel("gemini-1.5-pro")
            self.client = MemoryClient(api_key=os.getenv("MEM0_KEY"))
            self.sutra_api_key = os.getenv("SUTRA_KEY")
            return True
        except Exception as e:
            st.error(f"API init failed: {e}")
            return False

    def call_sutra_api(self, prompt, max_tokens=1000):
        headers = {
            "Authorization": f"Bearer {self.sutra_api_key}",
            "Content-Type": "application/json"
        }
        data = {
            "model": "sutra-v2",
            "messages": [{"role": "user", "content": prompt}],
            "max_tokens": max_tokens,
            "temperature": 0.7
        }
        response = requests.post(self.sutra_base_url, headers=headers, json=data, timeout=30)
        if response.status_code == 200:
            return response.json()["choices"][0]["message"]["content"].strip()
        else:
            raise Exception(f"API error: {response.status_code} {response.text}")

    def translate_text(self, text, target_language):
        if target_language == "English":
            return text
        prompt = f"Translate to {target_language}: {text}"
        return self.call_sutra_api(prompt, max_tokens=200)

    def get_chat_response(self, query, user_id, selected_language):
        query_en = query if selected_language == "English" else self.call_sutra_api(
            f"Translate this to English: {query}", max_tokens=200
        )
        search_results = self.client.search(query_en, user_id=user_id)
        mem0_memories = [r.get("message", {}).get("content", r.get("memory", "")) for r in search_results]
        context = "\n".join(mem0_memories)

        prompt = f"""
        You are a diabetes-friendly AI assistant.
        Context from user memory:
        {context}

        Query: {query_en}
        Respond in {selected_language}.
        """
        response = self.gemini.generate_content(prompt).text
        if selected_language != "English":
            response = self.translate_text(response, selected_language)

        self.client.add([{ "role": "user", "content": query},
                         { "role": "assistant", "content": response}], user_id=user_id)
        return response

    def log_health_data(self, user_id, exercise, diet, sugar_level):
        log_entry = f"Exercise: {exercise}\nDiet: {diet}\nSugar Level: {sugar_level}"
        self.client.add([{ "role": "system", "content": log_entry}], user_id=user_id)
        return log_entry


# --------------------------
# Streamlit App
# --------------------------
def main():
    st.set_page_config(page_title="Diabetes Health Assistant", page_icon="🩺", layout="wide")
    st.title("🩺 Diabetes Health Assistant")
    st.caption("Your personalized diabetes management companion")

    if "assistant" not in st.session_state:
        st.session_state.assistant = DiabetesHealthAssistant()
    if "chat_history" not in st.session_state:
        st.session_state.chat_history = []
    if "user_id" not in st.session_state:
        st.session_state.user_id = None
    if "language" not in st.session_state:
        st.session_state.language = "English"

    # Sidebar for setup
    with st.sidebar:
        st.header("🔑 API Configuration")
        sutra_key = st.text_input("SUTRA API Key", type="password")
        mem0_key = st.text_input("Mem0 API Key", type="password")
        gemini_key = st.text_input("Gemini API Key", type="password")
        language = st.selectbox("Select Language", st.session_state.assistant.languages, index=0)
        if st.button("Initialize"):
            ok = st.session_state.assistant.initialize_apis()
            if ok:
                st.session_state.language = language
                st.success("APIs initialized!")

    if not getattr(st.session_state.assistant, "client", None):
        st.warning("Enter API keys in sidebar to continue.")
        return

    # User login/registration
    if not st.session_state.user_id:
        st.subheader("👤 User Login")
        user_id = st.text_input("Enter your unique username/ID")
        if st.button("Login"):
            if user_id.strip():
                st.session_state.user_id = user_id.strip()
                st.success(f"Logged in as {st.session_state.user_id}")
            else:
                st.error("Enter a valid ID.")
        return

    # --------------------------
    # Logging UI
    # --------------------------
    st.subheader("📊 Log Your Health Data")
    with st.form("log_form"):
        exercise = st.text_input("Exercise (e.g., 30 min jogging, 100 pushups)")
        diet = st.text_input("Diet (e.g., 2 chapatis, rice, dal)")
        sugar_level = st.number_input("Sugar Level (mg/dL)", min_value=50, max_value=400, step=1)
        submitted = st.form_submit_button("Log Data")
        if submitted:
            entry = st.session_state.assistant.log_health_data(
                st.session_state.user_id, exercise, diet, sugar_level
            )
            st.success("Health data logged!")

    # --------------------------
    # Chat + Voice
    # --------------------------
    st.subheader("💬 Chat with Assistant")
    for msg in st.session_state.chat_history:
        with st.chat_message(msg["role"]):
            st.markdown(msg["content"])

    query = None

    # Option 1: text input
    query = st.chat_input("Type your question...")

    # Option 2: voice input
    audio_bytes = st.audio_input("🎤 Speak your query")
    if audio_bytes is not None:
        st.audio(audio_bytes, format="audio/wav")
        if st.button("Transcribe & Send"):
            with st.spinner("Transcribing..."):
                query = transcribe_audio(audio_bytes.getvalue())
            st.success(f"You said: {query}")

    if query:
        st.session_state.chat_history.append({"role": "user", "content": query})
        with st.chat_message("user"):
            st.markdown(query)

        with st.chat_message("assistant"):
            with st.spinner("Thinking..."):
                response = st.session_state.assistant.get_chat_response(
                    query,
                    st.session_state.user_id,
                    st.session_state.language
                )
                st.markdown(response)
        st.session_state.chat_history.append({"role": "assistant", "content": response})


if __name__ == "__main__":
    main()
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py --server.port 8502 --server.headless true
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# /home/shaurya/miniconda3/envs/Diabetes/lib/python3.9/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8502
#   Network URL: http://172.16.163.157:8502
#   External URL: http://117.203.246.41:8502
